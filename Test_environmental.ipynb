# %%
from geotools import environmental

# %%
filename = './testfiles/environmental/4135_180deg_IL_SPL_MFC.E1N'

# %%
my_env_data = environmental.EnvDataAzm(filename, azimuth=180, datasetname='Dataset 1')
# Out:
# Azimuth slice at 180 degrees created

# %%
my_env_data.df
# Out:
#          Range   Depth         SPL
# 0        100.0    20.0  196.648829
# 1        100.0    40.0  199.330459
# 2        100.0    60.0  195.204364
# 3        100.0    80.0  196.807217
# 4        100.0   100.0  197.341363
# ...        ...     ...         ...
# 59995  60000.0  1920.0  135.246645
# 59996  60000.0  1940.0  135.347519
# 59997  60000.0  1960.0  135.454191
# 59998  60000.0  1980.0  135.570489
# 59999  60000.0  2000.0  135.673957
#
# [60000 rows x 3 columns]

# %%
print(my_env_data.datasetname)
# Out:
# Dataset 1

# %%
my_env_data.limit(maxdepth=1500, maxoffset=40000)

# %%
my_env_data.plot()

# %%
my_env_data.mirror_azm()

# %%
my_env_data.plot()

# %%
my_env_data.shift_and_limit(40000, 100, 39900)

# %%
my_env_data.plot()

# %%
my_env_data2 = environmental.EnvDataAzm(filename, azimuth=180, datasetname='Dataset 2')
# Out:
# Azimuth slice at 180 degrees created

# %%
my_env_data2.plot()

# %%
my_env_data2.limit(maxdepth=1500, maxoffset=40000)

# %%
my_env_data2.plot()

# %%
#my_env_data.dB_add(my_env_data2)

# %%
my_env_data.plot()

# %%
my_env_data.df
# Out:
#          Range   Depth         SPL
# 0        100.0    20.0  104.074084
# 1        100.0    40.0  109.963872
# 2        100.0    60.0  112.574139
# 3        100.0    80.0  115.402176
# 4        100.0   100.0  117.823616
# ...        ...     ...         ...
# 29920  39900.0  1420.0  186.938161
# 29921  39900.0  1440.0  186.821278
# 29922  39900.0  1460.0  186.703956
# 29923  39900.0  1480.0  186.586690
# 29924  39900.0  1500.0  186.469511
#
# [29925 rows x 3 columns]

# %%
my_env_data.dB_add(my_env_data2)

# %%
my_env_data.plot()

# %%
my_env_data3 = environmental.EnvDataAzm(filename, azimuth=180, datasetname='Dataset 3')
# Out:
# Azimuth slice at 180 degrees created

# %%
my_env_data3.mirror_azm()

# %%
my_env_data3.shift_and_limit(10000, 100, 39900)

# %%
my_env_data3.plot()

# %%
my_env_data.dB_add(my_env_data3)

# %%
my_env_data.plot()

# %%
environmental.plot_graph(100, my_env_data2, my_env_data3, my_env_data)
# Out:
# Dataset 2
# Dataset 3 - Mirrored - Shifted
# Dataset 1 - Mirrored - Shifted - Added Dataset 2 - Added Dataset 3 - Mirrored - Shifted

# %%
environmental.plot_graph(100, my_env_data2, my_env_data3, my_env_data, x_lim=(0, 40000), y_lim=(100, 220),)
# Out:
# Dataset 2
# Dataset 3 - Mirrored - Shifted
# Dataset 1 - Mirrored - Shifted - Added Dataset 2 - Added Dataset 3 - Mirrored - Shifted

# %%
my_env_data.rename('All Combined')
my_env_data2.rename('Primary Source')
my_env_data3.rename('CLO')

# %%
environmental.plot_graph(1000, my_env_data2, my_env_data3, my_env_data)
# Out:
# Primary Source
# CLO
# All Combined
