# %%
from geotools import offset_dist

# %%
path = './testfiles/nearoffset_dist/Eq_Arg/'
filenames = {'Standard Triple Source - 12x75': path + '12x75mx6000m_TS.A1X',
            'Wide Tow Source - Equinor - 12x 75': path + '12x75mx8000m_Equinor.A1X'}

# %%
path = './testfiles/nearoffset_dist/Eq_Arg/'
filenames = {'Standard Triple Source - 12x93.75': path + '12x93,75mx6000m_MW.A1X',
            'Wide Tow Source - 12x93.75': path + '12x93,75mx6000m_WT_MW.A1X'}

# %%
path = './testfiles/nearoffset_dist/Eq_Arg/'
filenames = {'Standard Triple Source - 12x75': path + '12x75mx6000m_TS.A1X',
            'Wide Tow Source - 12x75': path + '12x75mx8000m_Equinor.A1X',
            'Standard Triple Source - 12x93.75': path + '12x93,75mx6000m_MW.A1X',
            'Wide Tow Source - 12x93.75': path + '12x93,75mx6000m_WT_MW.A1X'}

# %%
my_offset_data = offset_dist.OffsetData(filenames)
# Out:
# Reading configuration:  Standard Triple Source - 12x75
# From file:  ./testfiles/nearoffset_dist/Eq_Arg/12x75mx6000m_TS.A1X
# Reading configuration:  Wide Tow Source - 12x75
# From file:  ./testfiles/nearoffset_dist/Eq_Arg/12x75mx8000m_Equinor.A1X
# Reading configuration:  Standard Triple Source - 12x93.75
# From file:  ./testfiles/nearoffset_dist/Eq_Arg/12x93,75mx6000m_MW.A1X
# Reading configuration:  Wide Tow Source - 12x93.75
# From file:  ./testfiles/nearoffset_dist/Eq_Arg/12x93,75mx6000m_WT_MW.A1X

# %%
my_offset_data.df
# Out:
#         numRows  ShotNo  StrNo  RecNo       Offset     MidPtX    MidPtY  \
# 0             0     1.0    1.0    1.0   400.195265  10437.500  10000.00
# 1             1     1.0    1.0    2.0   403.500310  10437.500   9993.75
# 2             2     1.0    1.0    3.0   407.162437  10437.500   9987.50
# 3             3     1.0    1.0    4.0   411.172105  10437.500   9981.25
# 4             4     1.0    1.0    5.0   415.519253  10437.500   9975.00
# ...         ...     ...    ...    ...          ...        ...       ...
# 259191    69114     3.0   12.0  636.0  8010.326585  11109.375   6056.25
# 259192    69115     3.0   12.0  637.0  8022.806491  11109.375   6050.00
# 259193    69116     3.0   12.0  638.0  8035.286678  11109.375   6043.75
# 259194    69117     3.0   12.0  639.0  8047.766647  11109.375   6037.50
# 259195    69118     3.0   12.0  640.0  8060.247391  11109.375   6031.25
#
#            DipSrc      DipRec      AzSrc  ...      Absorp   ReflCRe  ReflCIm  \
# 0        8.107396  171.892609  75.532486  ...  187.756241  0.020261      0.0
# 1        8.167556  171.832443  73.815208  ...  187.740585  0.020226      0.0
# 2        8.238458  171.761536  72.114517  ...  187.721985  0.020185      0.0
# 3        8.312439  171.687561  70.510780  ...  187.702362  0.020141      0.0
# 4        8.395432  171.604568  68.812469  ...  187.680145  0.020092      0.0
# ...           ...         ...        ...  ...         ...       ...      ...
# 259191  32.966152  147.033844  -3.243113  ...  150.575546  0.009773      0.0
# 259192  32.967514  147.032486  -3.238151  ...  150.559814  0.009769      0.0
# 259193  32.968884  147.031113  -3.233114  ...  150.543976  0.009765      0.0
# 259194  32.970245  147.029755  -3.228089  ...  150.528168  0.009760      0.0
# 259195  32.971600  147.028397  -3.223079  ...  150.512421  0.009756      0.0
#
#          ReflCAm  ReflCPh      ReflPosX     ReflPosY   RefAngIn  RefAngOut  \
# 0       0.020261      0.0  10437.575195  9999.990234  12.049596  12.049449
# 1       0.020226      0.0  10437.494141  9993.767578  12.139632  12.139470
# 2       0.020185      0.0  10437.500000  9987.474609  12.245354  12.246061
# 3       0.020141      0.0  10437.496094  9981.431641  12.356536  12.357062
# 4       0.020092      0.0  10437.404297  9974.934570  12.481621  12.480893
# ...          ...      ...           ...          ...        ...        ...
# 259191  0.009773      0.0  11109.346680  6056.123047  53.654350  53.654339
# 259192  0.009769      0.0  11109.343750  6049.930664  53.657215  53.657204
# 259193  0.009765      0.0  11109.343750  6043.679199  53.660080  53.660080
# 259194  0.009760      0.0  11109.344727  6037.425293  53.662949  53.662960
# 259195  0.009756      0.0  11109.344727  6031.170898  53.665813  53.665825
#
#                          Configuration
# 0       Standard Triple Source - 12x75
# 1       Standard Triple Source - 12x75
# 2       Standard Triple Source - 12x75
# 3       Standard Triple Source - 12x75
# 4       Standard Triple Source - 12x75
# ...                                ...
# 259191      Wide Tow Source - 12x93.75
# 259192      Wide Tow Source - 12x93.75
# 259193      Wide Tow Source - 12x93.75
# 259194      Wide Tow Source - 12x93.75
# 259195      Wide Tow Source - 12x93.75
#
# [259196 rows x 23 columns]

# %%
my_offset_data.fill_empty_sublines()
# Out:
# Bin size seems to be 12.5 for the configuration Standard Triple Source - 12x75.
# Adding the following midpoints to Standard Triple Source - 12x75:
# Empty DataFrame
# Columns: [MidPtX, Configuration]
# Index: []
# Bin size seems to be 12.5 for the configuration Wide Tow Source - 12x75.
# Adding the following midpoints to Wide Tow Source - 12x75:
#      MidPtX            Configuration
# 0   11075.0  Wide Tow Source - 12x75
# 1   10500.0  Wide Tow Source - 12x75
# 2   11012.5  Wide Tow Source - 12x75
# 3   11112.5  Wide Tow Source - 12x75
# 4   10025.0  Wide Tow Source - 12x75
# 5   10537.5  Wide Tow Source - 12x75
# 6   11500.0  Wide Tow Source - 12x75
# 7   10062.5  Wide Tow Source - 12x75
# 8   11025.0  Wide Tow Source - 12x75
# 9   10450.0  Wide Tow Source - 12x75
# 10  11537.5  Wide Tow Source - 12x75
# 11  10550.0  Wide Tow Source - 12x75
# 12  10487.5  Wide Tow Source - 12x75
# 13  11062.5  Wide Tow Source - 12x75
# 14  10587.5  Wide Tow Source - 12x75
# 15  10012.5  Wide Tow Source - 12x75
# 16  11550.0  Wide Tow Source - 12x75
# 17  10975.0  Wide Tow Source - 12x75
# Bin size seems to be 15.625 for the configuration Standard Triple Source - 12x93.75.
# Adding the following midpoints to Standard Triple Source - 12x93.75:
# Empty DataFrame
# Columns: [MidPtX, Configuration]
# Index: []
# Bin size seems to be 15.625 for the configuration Wide Tow Source - 12x93.75.
# Adding the following midpoints to Wide Tow Source - 12x93.75:
#       MidPtX               Configuration
# 0  10000.000  Wide Tow Source - 12x93.75
# 1  11671.875  Wide Tow Source - 12x93.75

# %%
my_offset_data.df
# Out:
#             Absorp      AzRec      AzSrc                   Configuration  \
# 0       187.756241  75.532486  75.532486  Standard Triple Source - 12x75
# 1       187.740585  73.815208  73.815208  Standard Triple Source - 12x75
# 2       187.721985  72.114517  72.114517  Standard Triple Source - 12x75
# 3       187.702362  70.510780  70.510780  Standard Triple Source - 12x75
# 4       187.680145  68.812469  68.812469  Standard Triple Source - 12x75
# ...            ...        ...        ...                             ...
# 259211         NaN        NaN        NaN         Wide Tow Source - 12x75
# 259212         NaN        NaN        NaN         Wide Tow Source - 12x75
# 259213         NaN        NaN        NaN         Wide Tow Source - 12x75
# 259214         NaN        NaN        NaN      Wide Tow Source - 12x93.75
# 259215         NaN        NaN        NaN      Wide Tow Source - 12x93.75
#
#             DipRec    DipSrc    Geospr     MidPtX    MidPtY      Offset  ...  \
# 0       171.892609  8.107396  0.000345  10437.500  10000.00  400.195265  ...
# 1       171.832443  8.167556  0.000345  10437.500   9993.75  403.500310  ...
# 2       171.761536  8.238458  0.000345  10437.500   9987.50  407.162437  ...
# 3       171.687561  8.312439  0.000345  10437.500   9981.25  411.172105  ...
# 4       171.604568  8.395432  0.000344  10437.500   9975.00  415.519253  ...
# ...            ...       ...       ...        ...       ...         ...  ...
# 259211         NaN       NaN       NaN  10012.500       NaN         NaN  ...
# 259212         NaN       NaN       NaN  11550.000       NaN         NaN  ...
# 259213         NaN       NaN       NaN  10975.000       NaN         NaN  ...
# 259214         NaN       NaN       NaN  10000.000       NaN         NaN  ...
# 259215         NaN       NaN       NaN  11671.875       NaN         NaN  ...
#
#          ReflCAm  ReflCIm  ReflCPh   ReflCRe      ReflPosX     ReflPosY  \
# 0       0.020261      0.0      0.0  0.020261  10437.575195  9999.990234
# 1       0.020226      0.0      0.0  0.020226  10437.494141  9993.767578
# 2       0.020185      0.0      0.0  0.020185  10437.500000  9987.474609
# 3       0.020141      0.0      0.0  0.020141  10437.496094  9981.431641
# 4       0.020092      0.0      0.0  0.020092  10437.404297  9974.934570
# ...          ...      ...      ...       ...           ...          ...
# 259211       NaN      NaN      NaN       NaN           NaN          NaN
# 259212       NaN      NaN      NaN       NaN           NaN          NaN
# 259213       NaN      NaN      NaN       NaN           NaN          NaN
# 259214       NaN      NaN      NaN       NaN           NaN          NaN
# 259215       NaN      NaN      NaN       NaN           NaN          NaN
#
#         ShotNo  StrNo     Ttime  numRows
# 0          1.0    1.0  0.754222      0.0
# 1          1.0    1.0  0.754520      1.0
# 2          1.0    1.0  0.754874      2.0
# 3          1.0    1.0  0.755247      3.0
# 4          1.0    1.0  0.755670      4.0
# ...        ...    ...       ...      ...
# 259211     NaN    NaN       NaN      NaN
# 259212     NaN    NaN       NaN      NaN
# 259213     NaN    NaN       NaN      NaN
# 259214     NaN    NaN       NaN      NaN
# 259215     NaN    NaN       NaN      NaN
#
# [259216 rows x 23 columns]

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-4f76a9dad686> in <module>()
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
my_offset_data.plot_swarm(offsetlim=600, xtickinc=4)

# %%
my_offset_data.offset_limit(upper=800)

# %%
my_offset_data.makeoffsetclass(0, 800, 25)
# Out:
# /Volumes/Macintosh HD 2/Users/magnuswangensteen/Coding/Geotools/geotools/offset_dist.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df['Offsetclass'] = pd.cut(self.df['Offset'], offset_planes)

# %%
my_offset_data.hist_offsetclass()

# %%
my_offset_data.offsetclassbinning()
# Out:
# Bin size seems to be 12.5 for the configuration Standard Triple Source - 12x75.
# 11075.0
# 10500.0
# 11012.5
# 11112.5
# 10025.0
# 10537.5
# 11500.0
# 10062.5
# 11025.0
# 10450.0
# 11537.5
# 10550.0
# 10487.5
# 11062.5
# 10587.5
# 10012.5
# 11550.0
# 10975.0
# Bin size seems to be 12.5 for the configuration Wide Tow Source - 12x75.
# Bin size seems to be 15.625 for the configuration Standard Triple Source - 12x93.75.
# 10000.0
# 11671.875
# Bin size seems to be 15.625 for the configuration Wide Tow Source - 12x93.75.

# %%
my_offset_data.plot_offset_bins(maxfold=13)

# %%
#my_offset_data.compute_offset_components()

# %%
#my_offset_data_5seq.makeoffsetclass(0, 600, 25)

# %%
my_offset_data.plot_empty_bins(y_max=32)

# %%
my_offset_data.plot_empty_bins(range=True, y_max=500)

# %%
my_offset_data.x_limit(lower=10000, upper=11000)

# %%
#sns.axes_style()

# %%
#my_offset_data_5seq.df

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
#dwot = my_offset_data_5seq.df[(my_offset_data_5seq.df['Configuration'] == 'Dual Source Wide on Top')]

# %%
my_offset_data.df = my_offset_data.df[(my_offset_data.df['Configuration'] == 'Wide Tow Source - 12x93.75')]

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(16, 12))
sns.swarmplot(x='MidPtX', y='AzSrc', data=my_offset_data.df[(my_offset_data.df['Offset'] <= 600)], hue='Configuration')
#plt.ylim(600, 0)
plt.show()

# %%
test_off_class = my_offset_data.df[(my_offset_data.df['Offset'] <= 250) & (my_offset_data.df['Offset'] >= 150)]

# %%
test_off_class

# %%
#test_off_class_conf1 = test_off_class[(test_off_class['Configuration']) == 'Standard Triple Source - 12x75']
#test_off_class_conf2 = test_off_class[(test_off_class['Configuration']) == 'Wide Tow Source - Equinor - 12x 75']

# %%
#test_off_class_conf1 = test_off_class[(test_off_class['Configuration']) == 'Standard Triple Source - 12x93.75']
test_off_class_conf2 = test_off_class[(test_off_class['Configuration']) == 'Wide Tow Source - 12x93.75']

# %%
#conf1 = test_off_class_conf1.groupby(['MidPtX'])['AzSrc'].describe().reset_index()
conf2 = test_off_class_conf2.groupby(['MidPtX'])['AzSrc'].describe().reset_index()

# %%
conf2

# %%
import numpy as np
import pandas as pd

# %%
midxlist = set(np.arange(10000, 11012.5, 12.5))

# %%
midxlist = set(np.arange(10000, 11015.625, 15.625))

# %%
#midxlistalready1 = set(conf1['MidPtX'])
midxlistalready2 = set(conf2['MidPtX'])

# %%
#add_midx1 = list(midxlist.difference(midxlistalready1))
add_midx2 = list(midxlist.difference(midxlistalready2))

# %%
#labels1 = {'MidPtX': add_midx1, 'count': np.nan, 'mean': np.nan, 'std': np.nan, 'min': np.nan, '25%': np.nan,'50%': np.nan, '75%': np.nan, 'max': np.nan}
#temp1 = pd.DataFrame(labels1)
labels2 = {'MidPtX': add_midx2, 'count': np.nan, 'mean': np.nan, 'std': np.nan, 'min': np.nan, '25%': np.nan,'50%': np.nan, '75%': np.nan, 'max': np.nan}
temp2 = pd.DataFrame(labels2)

# %%
#temp2

# %%
#conf1 = conf1.append(temp1).sort_values(['MidPtX'])
conf2 = conf2.append(temp2).sort_values(['MidPtX'])

# %%
#conf1 = conf1.reset_index()
conf2 = conf2.reset_index()

# %%
print(conf2['mean'])

# %%
sns.set_style('white', {'axes.grid': True, 
            'xtick.bottom': True, 
            'xtick.top': True,
            'ytick.left': True, 
            'ytick.right': True,
            })
plt.figure(figsize=(16, 12))
sns.swarmplot(x='MidPtX', y='AzSrc', data=my_offset_data.df[(my_offset_data.df['Offset'] <= 550) & (my_offset_data.df['Offset'] >= 250)], hue='Configuration')
#sns.boxplot(x='MidPtX', y='AzSrc', data=my_offset_data.df[(my_offset_data.df['Offset'] <= 550) & (my_offset_data.df['Offset'] >= 250)], hue='Configuration')
#sns.lineplot(data=conf1['mean'])
#sns.lineplot(data=conf2['mean'])
#plt.ylim(-180, 180)
locs, labels = plt.xticks()
plt.xticks(locs[::2], labels[::2], rotation=-90)
#for loc in locs:
#    plt.axvline(x=loc+0.5, color='grey')
plt.title("Subselection: Absolute offset: [250, 550]m")
plt.show()

# %%
my_offset_data.df.columns

# %%
sns.set_style('white', {'axes.grid': True, 
            'xtick.bottom': True, 
            'xtick.top': True,
            'ytick.left': True, 
            'ytick.right': True,
            })
plt.figure(figsize=(24, 12))
#sns.swarmplot(x='MidPtX', y='Ttime', data=my_offset_data.df[(my_offset_data.df['Offset'] <= 250) & (my_offset_data.df['Offset'] >= 150)], hue='Configuration')
sns.boxplot(x='MidPtX', y='Ttime', data=my_offset_data.df[(my_offset_data.df['Offset'] <= 250) & (my_offset_data.df['Offset'] >= 150)], hue='Configuration')
#sns.lineplot(data=conf1['mean'])
#sns.lineplot(data=conf2['mean'])
#plt.ylim(-180, 180)
locs, labels = plt.xticks()
plt.xticks(locs[::1], labels[::1], rotation=-90)
#for loc in locs:
#    plt.axvline(x=loc+0.5, color='grey')
plt.title("Subselection: Absolute offset: [150, 250]m")
plt.show()

# %%
print(my_offset_data.num_offset_planes)

# %%
my_offset_data.df['MidPtX'].min()

# %%
dict_test = {}
dict_test['test1'] = list(np.arange(1, 10, 3))

# %%
dict_test

# %%
dict_test['Test2'] = [4, 3, 2]

# %%
dict_test

# %%
df_test = pd.DataFrame()

# %%
df_test

# %%
df2_test = pd.DataFrame(dict_test)

# %%
df_test = df_test.append(df2_test, ignore_index=True)

# %%
df_test
