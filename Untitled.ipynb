# %%
from GStools import infill_modeling

# %%
my_imod_job = infill_modeling.IModJob()
# Out:
# Initialization complete!

# %%
my_imod_job.df_vessel
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
filename = './testfiles/infill/infill/L38_vels.A1X'

# %%
my_imod_job.read_col_data(filename)

# %%
my_imod_job.df_vels
# Out:
#        Depth       Vp
# 0        0.0  1518.67
# 1      100.0  1518.67
# 2      200.0  1569.14
# 3      300.0  1638.93
# 4      400.0  1699.60
# ..       ...      ...
# 139  13900.0  4956.26
# 140  14000.0  4962.65
# 141  14100.0  4969.05
# 142  14200.0  4975.44
# 143  14300.0  4981.83
#
# [144 rows x 2 columns]

# %%
my_imod_job.make_model(waterdepth=200, max_depth=10000, watervel=1550, Qp=120)
# Out:
# Water velocity set to: 1550
# Max depth is: 10000
# The depths defined in the model are: [200, 700, 1200, 1700, 2200, 2700, 3200, 3700, 4200, 4700, 5200, 5700, 6200, 6700, 7200, 7700, 8200, 8700, 9200, 9700, 10200]

# %%
my_imod_job.df_plm_model
# Out:
#     Intf  Depth      Vp      Vs  Density      Qp        Qs
# 0      1      0   330.0     0.0     0.01  100000  100000.0
# 1      2    200  1550.0     0.0     1.00   10000   10000.0
# 2      3    700  1710.6   987.6     1.99     120      90.0
# 3      4   1200  1932.1  1115.5     2.05     120      90.0
# 4      5   1700  2119.6  1223.8     2.10     120      90.0
# 5      6   2200  2284.0  1318.7     2.14     120      90.0
# 6      7   2700  2424.6  1399.8     2.17     120      90.0
# 7      8   3200  2548.6  1471.4     2.20     120      90.0
# 8      9   3700  2669.2  1541.1     2.23     120      90.0
# 9     10   4200  2796.1  1614.3     2.25     120      90.0
# 10    11   4700  2932.9  1693.3     2.28     120      90.0
# 11    12   5200  3080.6  1778.6     2.31     120      90.0
# 12    13   5700  3250.2  1876.5     2.34     120      90.0
# 13    14   6200  3433.3  1982.2     2.37     120      90.0
# 14    15   6700  3626.6  2093.8     2.40     120      90.0
# 15    16   7200  3823.0  2207.2     2.43     120      90.0
# 16    17   7700  4010.2  2315.3     2.46     120      90.0
# 17    18   8200  4165.5  2405.0     2.49     120      90.0
# 18    19   8700  4314.3  2490.9     2.51     120      90.0
# 19    20   9200  4455.7  2572.5     2.53     120      90.0
# 20    21   9700  4545.5  2624.3     2.54     120      90.0

# %%
my_imod_job.plot_vels()

# %%
my_imod_job.compute_mute_offset(100)
# Out:
# Mute angle is: 60.0

# %%
my_imod_job.df_plm_mutes
# Out:
#     Intf  Depth  Thickness       TWT  100% /60.0 deg mute offset
# 0      1      0        NaN       NaN                         NaN
# 1      2    200      200.0  0.258065                  692.820323
# 2      3    700      500.0  0.842655                 2238.441353
# 3      4   1200      500.0  1.360226                 3312.818819
# 4      5   1700      500.0  1.832013                 4322.596262
# 5      6   2200      500.0  2.269842                 5301.712661
# 6      7   2700      500.0  2.682281                 6292.847457
# 7      8   3200      500.0  3.074653                 7287.357025
# 8      9   3700      500.0  3.449297                 8232.101313
# 9     10   4200      500.0  3.806938                 9086.202540
# 10    11   4700      500.0  4.147898                 9845.884739
# 11    12   5200      500.0  4.472510                10522.955256
# 12    13   5700      500.0  4.780183                11067.130629
# 13    14   6200      500.0  5.071448                11559.619594
# 14    15   6700      500.0  5.347189                12027.955292
# 15    16   7200      500.0  5.608763                12512.708604
# 16    17   7700      500.0  5.858127                13072.057068
# 17    18   8200      500.0  6.098195                13814.505436
# 18    19   8700      500.0  6.329982                14567.889766
# 19    20   9200      500.0  6.554414                15341.384033
# 20    21   9700      500.0  6.774411                16426.620876

# %%
my_imod_job.makeoffsetclass(100, 8100, 4)
# Out:
# {'Group1': (100.0, 2100.0), 'Group2': (2100.0, 4100.0), 'Group3': (4100.0, 6100.0), 'Group4': (6100.0, 8100.0)}

# %%
print(my_imod_job.offsetgroups)
# Out:
# {'Group1': (100.0, 2100.0), 'Group2': (2100.0, 4100.0), 'Group3': (4100.0, 6100.0), 'Group4': (6100.0, 8100.0)}
